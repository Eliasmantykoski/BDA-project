# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import stan # python3 -m pip install pystan
import nest_asyncio
nest_asyncio.apply()
import warnings

# %%
schools_data = {"J": 8,
                "y": [28,  8, -3,  7, -1,  1, 18, 12],
                "sigma": [15, 10, 16, 11,  9, 11, 10, 18]}

# %%
with open('stan/test.stan') as file:
    code = file.read()
    
print(code)
# Out:
# data {
#   int<lower=0> J;         // number of schools
#   array[J] real y;              // estimated treatment effects
#   array[J] real<lower=0> sigma; // standard error of effect estimates
# }
# parameters {
#   real mu;                // population treatment effect
#   real<lower=0> tau;      // standard deviation in treatment effects
#   vector[J] eta;          // unscaled deviation from mu by school
# }
# transformed parameters {
#   vector[J] theta = mu + tau * eta;        // school treatment effects
# }
# model {
#   target += normal_lpdf(eta | 0, 1);       // prior log-density
#   target += normal_lpdf(y | theta, sigma); // log-likelihood
# }

# %%
schools_code = """
data {
  int<lower=0> J;         // number of schools
  array[J] real y;              // estimated treatment effects
  array[J] real<lower=0> sigma; // standard error of effect estimates
}
parameters {
  real mu;                // population treatment effect
  real<lower=0> tau;      // standard deviation in treatment effects
  vector[J] eta;          // unscaled deviation from mu by school
}
transformed parameters {
  vector[J] theta = mu + tau * eta;        // school treatment effects
}
model {
  target += normal_lpdf(eta | 0, 1);       // prior log-density
  target += normal_lpdf(y | theta, sigma); // log-likelihood
}
"""

# %%
posterior = stan.build(schools_code, data=schools_data)
fit = posterior.sample(num_chains=4, num_samples=1000)
eta = fit["eta"]  # array with shape (8, 4000)
df = fit.to_frame()  # pandas `DataFrame, requires pandas
# Out:
# Building...
# In file included from /home/mantyke1/.cache/httpstan/4.6.1/models/tlxohk6n/model_tlxohk6n.cpp:2:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/model/model_header.hpp:4:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math.hpp:19:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/rev.hpp:8:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/rev/core.hpp:28:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/rev/core/operator_addition.hpp:6:
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/err/check_matching_dims.hpp:56:23: warning: comparison of integers of different signs: 'int' and 'std::vector::size_type' (aka 'unsigned long') [-Wsign-compare]
#     for (int i = 0; i < y1_d.size(); i++) {
#                     ~ ^ ~~~~~~~~~~~
# In file included from /home/mantyke1/.cache/httpstan/4.6.1/models/tlxohk6n/model_tlxohk6n.cpp:2:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/model/model_header.hpp:4:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math.hpp:19:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/rev.hpp:10:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/rev/fun.hpp:26:
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/rev/fun/beta.hpp:70:32: warning: lambda capture 'b' is not used [-Wunused-lambda-capture]
#                            [a, b, digamma_ab](auto& vi) mutable {
#                              ~~^
# In file included from /home/mantyke1/.cache/httpstan/4.6.1/models/tlxohk6n/model_tlxohk6n.cpp:2:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/model/model_header.hpp:4:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math.hpp:19:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/rev.hpp:10:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/rev/fun.hpp:55:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/rev/fun/elt_multiply.hpp:9:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/rev/fun/multiply.hpp:7:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/fun.hpp:124:
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/fun/grad_2F1.hpp:68:10: warning: unused variable 'log_precision' [-Wunused-variable]
#   double log_precision = log(precision);
#          ^
# In file included from /home/mantyke1/.cache/httpstan/4.6.1/models/tlxohk6n/model_tlxohk6n.cpp:2:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/model/model_header.hpp:4:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math.hpp:19:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/rev.hpp:10:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/rev/fun.hpp:128:
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/rev/fun/matrix_power.hpp:52:24: warning: comparison of integers of different signs: 'size_t' (aka 'unsigned long') and 'const int' [-Wsign-compare]
#   for (size_t i = 2; i <= n; ++i) {
#                      ~ ^  ~
# In file included from /home/mantyke1/.cache/httpstan/4.6.1/models/tlxohk6n/model_tlxohk6n.cpp:2:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/model/model_header.hpp:4:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math.hpp:19:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/rev.hpp:10:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/rev/fun.hpp:141:
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/rev/fun/ordered_constrain.hpp:40:30: warning: comparison of integers of different signs: 'Eigen::Index' (aka 'long') and 'size_t' (aka 'unsigned long') [-Wsign-compare]
#   for (Eigen::Index n = 1; n < N; ++n) {
#                            ~ ^ ~
# In file included from /home/mantyke1/.cache/httpstan/4.6.1/models/tlxohk6n/model_tlxohk6n.cpp:2:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/model/model_header.hpp:4:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math.hpp:19:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/rev.hpp:10:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/rev/fun.hpp:144:
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/rev/fun/positive_ordered_constrain.hpp:40:21: warning: comparison of integers of different signs: 'int' and 'size_t' (aka 'unsigned long') [-Wsign-compare]
#   for (int n = 1; n < N; ++n) {
#                   ~ ^ ~
# In file included from /home/mantyke1/.cache/httpstan/4.6.1/models/tlxohk6n/model_tlxohk6n.cpp:2:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/model/model_header.hpp:4:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math.hpp:19:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/rev.hpp:10:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/rev/fun.hpp:162:
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/rev/fun/simplex_constrain.hpp:40:30: warning: comparison of integers of different signs: 'Eigen::Index' (aka 'long') and 'size_t' (aka 'unsigned long') [-Wsign-compare]
#   for (Eigen::Index k = 0; k < N; ++k) {
#                            ~ ^ ~
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/rev/fun/simplex_constrain.hpp:94:30: warning: comparison of integers of different signs: 'Eigen::Index' (aka 'long') and 'size_t' (aka 'unsigned long') [-Wsign-compare]
#   for (Eigen::Index k = 0; k < N; ++k) {
#                            ~ ^ ~
# In file included from /home/mantyke1/.cache/httpstan/4.6.1/models/tlxohk6n/model_tlxohk6n.cpp:2:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/model/model_header.hpp:4:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math.hpp:19:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/rev.hpp:10:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/rev/fun.hpp:198:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/functor.hpp:12:
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/functor/hcubature.hpp:73:29: warning: comparison of integers of different signs: 'std::size_t' (aka 'unsigned long') and 'int' [-Wsign-compare]
#   for (std::size_t i = 0; i < p - 1; i++) {
#                           ~ ^ ~~~~~
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/functor/hcubature.hpp:79:16: warning: comparison of integers of different signs: 'size_t' (aka 'unsigned long') and 'const int' [-Wsign-compare]
#     } while (k < x);
#              ~ ^ ~
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/functor/hcubature.hpp:102:29: warning: comparison of integers of different signs: 'std::size_t' (aka 'unsigned long') and 'int' [-Wsign-compare]
#   for (std::size_t i = 1; i != choose_dimk + 1; i++) {
#                           ~ ^  ~~~~~~~~~~~~~~~
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/functor/hcubature.hpp:105:31: warning: comparison of integers of different signs: 'std::size_t' (aka 'unsigned long') and 'const int' [-Wsign-compare]
#     for (std::size_t j = 0; j != k; j++) {
#                             ~ ^  ~
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/functor/hcubature.hpp:126:31: warning: comparison of integers of different signs: 'std::size_t' (aka 'unsigned long') and 'const int' [-Wsign-compare]
#     for (std::size_t j = 0; j != k; j++) {
#                             ~ ^  ~
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/functor/hcubature.hpp:132:22: warning: comparison of integers of different signs: 'int' and 'std::vector<bool, type-parameter-0-0>::size_type' (aka 'unsigned long') [-Wsign-compare]
#   while ((first_zero < index.size()) && index[first_zero]) {
#           ~~~~~~~~~~ ^ ~~~~~~~~~~~~
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/functor/hcubature.hpp:135:18: warning: comparison of integers of different signs: 'int' and 'std::vector<bool, type-parameter-0-0>::size_type' (aka 'unsigned long') [-Wsign-compare]
#   if (first_zero == index.size()) {
#       ~~~~~~~~~~ ^  ~~~~~~~~~~~~
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/functor/hcubature.hpp:143:31: warning: comparison of integers of different signs: 'std::size_t' (aka 'unsigned long') and 'int' [-Wsign-compare]
#     for (std::size_t i = 0; i != first_zero + 1; i++) {
#                             ~ ^  ~~~~~~~~~~~~~~
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/functor/hcubature.hpp:168:29: warning: comparison of integers of different signs: 'std::size_t' (aka 'unsigned long') and 'int' [-Wsign-compare]
#   for (std::size_t i = 1; i != choose_dimk + 1; i++) {
#                           ~ ^  ~~~~~~~~~~~~~~~
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/functor/hcubature.hpp:281:29: warning: comparison of integers of different signs: 'std::size_t' (aka 'unsigned long') and 'const int' [-Wsign-compare]
#   for (std::size_t i = 0; i != dim; i++) {
#                           ~ ^  ~~~
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/functor/hcubature.hpp:285:29: warning: comparison of integers of different signs: 'std::size_t' (aka 'unsigned long') and 'const int' [-Wsign-compare]
#   for (std::size_t i = 0; i != dim; i++) {
#                           ~ ^  ~~~
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/functor/hcubature.hpp:289:29: warning: comparison of integers of different signs: 'std::size_t' (aka 'unsigned long') and 'const int' [-Wsign-compare]
#   for (std::size_t i = 0; i != dim; i++) {
#                           ~ ^  ~~~
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/functor/hcubature.hpp:308:29: warning: comparison of integers of different signs: 'std::size_t' (aka 'unsigned long') and 'const int' [-Wsign-compare]
#   for (std::size_t i = 0; i != dim; i++) {
#                           ~ ^  ~~~
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/functor/hcubature.hpp:309:31: warning: comparison of integers of different signs: 'std::size_t' (aka 'unsigned long') and 'const int' [-Wsign-compare]
#     for (std::size_t j = 0; j != dim; j++) {
#                             ~ ^  ~~~
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/functor/hcubature.hpp:313:31: warning: comparison of integers of different signs: 'std::size_t' (aka 'unsigned long') and 'const int' [-Wsign-compare]
#     for (std::size_t j = 0; j != dim; j++) {
#                             ~ ^  ~~~
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/functor/hcubature.hpp:317:31: warning: comparison of integers of different signs: 'std::size_t' (aka 'unsigned long') and 'const int' [-Wsign-compare]
#     for (std::size_t j = 0; j != dim; j++) {
#                             ~ ^  ~~~
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/functor/hcubature.hpp:323:31: warning: comparison of integers of different signs: 'std::size_t' (aka 'unsigned long') and 'const int' [-Wsign-compare]
#     for (std::size_t j = 0; j != dim; j++) {
#                             ~ ^  ~~~
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/functor/hcubature.hpp:326:31: warning: comparison of integers of different signs: 'std::size_t' (aka 'unsigned long') and 'const int' [-Wsign-compare]
#     for (std::size_t j = 0; j != dim; j++) {
#                             ~ ^  ~~~
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/functor/hcubature.hpp:330:31: warning: comparison of integers of different signs: 'std::size_t' (aka 'unsigned long') and 'const int' [-Wsign-compare]
#     for (std::size_t j = 0; j != dim; j++) {
#                             ~ ^  ~~~
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/functor/hcubature.hpp:342:31: warning: comparison of integers of different signs: 'std::size_t' (aka 'unsigned long') and 'const int' [-Wsign-compare]
#     for (std::size_t j = 0; j != dim; j++) {
#                             ~ ^  ~~~
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/functor/hcubature.hpp:345:31: warning: comparison of integers of different signs: 'std::size_t' (aka 'unsigned long') and 'const int' [-Wsign-compare]
#     for (std::size_t j = 0; j != dim; j++) {
#                             ~ ^  ~~~
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/functor/hcubature.hpp:354:31: warning: comparison of integers of different signs: 'std::size_t' (aka 'unsigned long') and 'const int' [-Wsign-compare]
#     for (std::size_t j = 0; j != dim; j++) {
#                             ~ ^  ~~~
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/functor/hcubature.hpp:358:31: warning: comparison of integers of different signs: 'std::size_t' (aka 'unsigned long') and 'const int' [-Wsign-compare]
#     for (std::size_t j = 0; j != dim; j++) {
#                             ~ ^  ~~~
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/functor/hcubature.hpp:371:29: warning: comparison of integers of different signs: 'std::size_t' (aka 'unsigned long') and 'const int' [-Wsign-compare]
#   for (std::size_t i = 0; i != dim; i++) {
#                           ~ ^  ~~~
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/functor/hcubature.hpp:468:7: warning: unused variable 'kdiv' [-Wunused-variable]
#   int kdiv = kdivide;
#       ^
# In file included from /home/mantyke1/.cache/httpstan/4.6.1/models/tlxohk6n/model_tlxohk6n.cpp:2:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/model/model_header.hpp:4:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math.hpp:19:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/rev.hpp:11:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/rev/functor.hpp:16:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/rev/functor/dae.hpp:6:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/rev/functor/idas_integrator.hpp:5:
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/rev/functor/idas_service.hpp:93:28: warning: comparison of integers of different signs: 'size_t' (aka 'unsigned long') and 'int' [-Wsign-compare]
#     for (size_t is = 0; is < ns; ++is) {
#                         ~~ ^ ~~
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/rev/functor/idas_service.hpp:105:26: warning: comparison of integers of different signs: 'size_t' (aka 'unsigned long') and 'int' [-Wsign-compare]
#     for (size_t i = 0; i < n; ++i) {
#                        ~ ^ ~
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/rev/functor/idas_service.hpp:108:26: warning: comparison of integers of different signs: 'size_t' (aka 'unsigned long') and 'int' [-Wsign-compare]
#     for (size_t i = 0; i < n; ++i) {
#                        ~ ^ ~
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/rev/functor/idas_service.hpp:117:26: warning: comparison of integers of different signs: 'size_t' (aka 'unsigned long') and 'int' [-Wsign-compare]
#     for (size_t i = 0; i < n; ++i) {
#                        ~ ^ ~
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/rev/functor/idas_service.hpp:126:26: warning: comparison of integers of different signs: 'size_t' (aka 'unsigned long') and 'int' [-Wsign-compare]
#     for (size_t i = 0; i < n; ++i) {
#                        ~ ^ ~
# In file included from /home/mantyke1/.cache/httpstan/4.6.1/models/tlxohk6n/model_tlxohk6n.cpp:2:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/model/model_header.hpp:4:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math.hpp:19:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/rev.hpp:11:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/rev/functor.hpp:30:
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/rev/functor/finite_diff_hessian_auto.hpp:61:24: warning: comparison of integers of different signs: 'size_t' (aka 'unsigned long') and 'int' [-Wsign-compare]
#   for (size_t i = 0; i < d; ++i) {
#                      ~ ^ ~
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/rev/functor/finite_diff_hessian_auto.hpp:69:24: warning: comparison of integers of different signs: 'size_t' (aka 'unsigned long') and 'int' [-Wsign-compare]
#   for (size_t i = 0; i < d; ++i) {
#                      ~ ^ ~
# In file included from /home/mantyke1/.cache/httpstan/4.6.1/models/tlxohk6n/model_tlxohk6n.cpp:2:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/model/model_header.hpp:4:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math.hpp:19:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/rev.hpp:14:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim.hpp:16:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/prob.hpp:128:
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/prob/gaussian_dlm_obs_rng.hpp:41:21: warning: comparison of integers of different signs: 'int' and 'size_t' (aka 'unsigned long') [-Wsign-compare]
#   for (int i = 0; i < M; i++) {
#                   ~ ^ ~
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/prob/gaussian_dlm_obs_rng.hpp:98:7: warning: unused variable 'n' [-Wunused-variable]
#   int n = G.rows();  // number of states
#       ^
# In file included from /home/mantyke1/.cache/httpstan/4.6.1/models/tlxohk6n/model_tlxohk6n.cpp:2:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/model/model_header.hpp:4:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math.hpp:19:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/rev.hpp:14:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim.hpp:16:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/prob.hpp:210:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/prob/multi_student_t_log.hpp:5:
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/prob/multi_student_t_lpdf.hpp:56:10: warning: unused variable 'num_y' [-Wunused-variable]
#   size_t num_y = size_mvt(y);
#          ^
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/prob/multi_student_t_lpdf.hpp:57:10: warning: unused variable 'num_mu' [-Wunused-variable]
#   size_t num_mu = size_mvt(mu);
#          ^
# In file included from /home/mantyke1/.cache/httpstan/4.6.1/models/tlxohk6n/model_tlxohk6n.cpp:2:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/model/model_header.hpp:4:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math.hpp:19:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/rev.hpp:14:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim.hpp:16:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/prob.hpp:312:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/prob/skew_double_exponential_ccdf_log.hpp:5:
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/prob/skew_double_exponential_lccdf.hpp:78:13: warning: unused variable 'size_sigma' [-Wunused-variable]
#   const int size_sigma = stan::math::size(sigma);
#             ^
# In file included from /home/mantyke1/.cache/httpstan/4.6.1/models/tlxohk6n/model_tlxohk6n.cpp:2:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/model/model_header.hpp:6:
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/io/deserializer.hpp:337:28: warning: comparison of integers of different signs: 'size_t' (aka 'unsigned long') and 'Eigen::Index' (aka 'long') [-Wsign-compare]
#       for (size_t i = 0; i < m; ++i) {
#                          ~ ^ ~
# In file included from /home/mantyke1/.cache/httpstan/4.6.1/models/tlxohk6n/model_tlxohk6n.cpp:2:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/model/model_header.hpp:13:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/model/indexing.hpp:6:
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/model/indexing/assign.hpp:277:21: warning: comparison of integers of different signs: 'int' and 'std::vector::size_type' (aka 'unsigned long') [-Wsign-compare]
#   for (int i = 0; i < idx.ns_.size(); ++i) {
#                   ~ ^ ~~~~~~~~~~~~~~
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/model/indexing/assign.hpp:531:21: warning: comparison of integers of different signs: 'int' and 'std::vector::size_type' (aka 'unsigned long') [-Wsign-compare]
#   for (int i = 0; i < col_idx.ns_.size(); ++i) {
#                   ~ ^ ~~~~~~~~~~~~~~~~~~
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/model/indexing/assign.hpp:630:21: warning: comparison of integers of different signs: 'int' and 'std::vector::size_type' (aka 'unsigned long') [-Wsign-compare]
#   for (int j = 0; j < col_idx.ns_.size(); ++j) {
#                   ~ ^ ~~~~~~~~~~~~~~~~~~
# In file included from /home/mantyke1/.cache/httpstan/4.6.1/models/tlxohk6n/model_tlxohk6n.cpp:2:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/model/model_header.hpp:13:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/model/indexing.hpp:9:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/model/indexing/rvalue_varmat.hpp:7:
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/model/indexing/rvalue.hpp:268:21: warning: comparison of integers of different signs: 'int' and 'std::vector::size_type' (aka 'unsigned long') [-Wsign-compare]
#   for (int i = 0; i < idx.ns_.size(); ++i) {
#                   ~ ^ ~~~~~~~~~~~~~~
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/model/indexing/rvalue.hpp:559:21: warning: comparison of integers of different signs: 'int' and 'std::vector::size_type' (aka 'unsigned long') [-Wsign-compare]
#   for (int j = 0; j < col_idx.ns_.size(); ++j) {
#                   ~ ^ ~~~~~~~~~~~~~~~~~~
# In file included from /home/mantyke1/.cache/httpstan/4.6.1/models/tlxohk6n/model_tlxohk6n.cpp:2:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/model/model_header.hpp:13:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/model/indexing.hpp:9:
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/model/indexing/rvalue_varmat.hpp:66:21: warning: comparison of integers of different signs: 'int' and 'const std::vector::size_type' (aka 'const unsigned long') [-Wsign-compare]
#   for (int i = 0; i < ret_size; ++i) {
#                   ~ ^ ~~~~~~~~
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/model/indexing/rvalue_varmat.hpp:102:21: warning: comparison of integers of different signs: 'int' and 'const std::vector::size_type' (aka 'const unsigned long') [-Wsign-compare]
#   for (int i = 0; i < ret_rows; ++i) {
#                   ~ ^ ~~~~~~~~
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/model/indexing/rvalue_varmat.hpp:142:21: warning: comparison of integers of different signs: 'int' and 'const std::vector::size_type' (aka 'const unsigned long') [-Wsign-compare]
#   for (int j = 0; j < ret_size; ++j) {
#                   ~ ^ ~~~~~~~~
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/model/indexing/rvalue_varmat.hpp:183:21: warning: comparison of integers of different signs: 'int' and 'const std::vector::size_type' (aka 'const unsigned long') [-Wsign-compare]
#   for (int i = 0; i < ret_size; ++i) {
#                   ~ ^ ~~~~~~~~
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/model/indexing/rvalue_varmat.hpp:226:21: warning: comparison of integers of different signs: 'int' and 'const std::vector::size_type' (aka 'const unsigned long') [-Wsign-compare]
#   for (int i = 0; i < ret_rows; ++i) {
#                   ~ ^ ~~~~~~~~
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/model/indexing/rvalue_varmat.hpp:230:21: warning: comparison of integers of different signs: 'int' and 'const std::vector::size_type' (aka 'const unsigned long') [-Wsign-compare]
#   for (int j = 0; j < ret_cols; ++j) {
#                   ~ ^ ~~~~~~~~
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/model/indexing/rvalue_varmat.hpp:234:23: warning: comparison of integers of different signs: 'int' and 'const std::vector::size_type' (aka 'const unsigned long') [-Wsign-compare]
#     for (int i = 0; i < ret_rows; ++i) {
#                     ~ ^ ~~~~~~~~
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/model/indexing/rvalue_varmat.hpp:277:21: warning: comparison of integers of different signs: 'int' and 'const std::vector::size_type' (aka 'const unsigned long') [-Wsign-compare]
#   for (int j = 0; j < ret_cols; ++j) {
#                   ~ ^ ~~~~~~~~
# /home/mantyke1/.cache/httpstan/4.6.1/models/tlxohk6n/model_tlxohk6n.cpp:46:11: warning: variable 'pos__' set but not used [-Wunused-but-set-variable]
#       int pos__ = std::numeric_limits<int>::min();
#           ^
# /home/mantyke1/.cache/httpstan/4.6.1/models/tlxohk6n/model_tlxohk6n.cpp:222:11: warning: variable 'pos__' set but not used [-Wunused-but-set-variable]
#       int pos__ = std::numeric_limits<int>::min();
#           ^
# In file included from /home/mantyke1/.cache/httpstan/4.6.1/models/tlxohk6n/model_tlxohk6n.cpp:2:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/model/model_header.hpp:4:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math.hpp:19:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/rev.hpp:10:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/rev/fun.hpp:55:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/rev/fun/elt_multiply.hpp:9:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/rev/fun/multiply.hpp:7:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/fun.hpp:124:
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/fun/grad_2F1.hpp:192:12: warning: unused variable 'pre_mult' [-Wunused-variable]
#       auto pre_mult = a2 * pow(1 - z, -1 - a2);
#            ^
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/fun/grad_2F1.hpp:307:20: note: in instantiation of function template specialization 'stan::math::internal::grad_2F1_impl<true, true, true, true, double, double, double, double, double, std::tuple<double, double, double, double>>' requested here
#   return internal::grad_2F1_impl<true, true, true, true>(a1, a2, b1, z,
#                    ^
# In file included from /home/mantyke1/.cache/httpstan/4.6.1/models/tlxohk6n/model_tlxohk6n.cpp:2:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/model/model_header.hpp:4:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math.hpp:19:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/rev.hpp:8:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/rev/core.hpp:53:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/rev/core/profiling.hpp:9:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/err.hpp:4:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/err/check_2F1_converges.hpp:5:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/err/check_not_nan.hpp:5:
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/err/elementwise_check.hpp:153:24: warning: comparison of integers of different signs: 'size_t' (aka 'unsigned long') and 'Eigen::EigenBase::Index' (aka 'long') [-Wsign-compare]
#   for (size_t i = 0; i < x.size(); i++) {
#                      ~ ^ ~~~~~~~~
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/err/check_finite.hpp:29:3: note: in instantiation of function template specialization 'stan::math::elementwise_check<(lambda at /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/err/check_finite.hpp:29:21), Eigen::Matrix<double, 2, 1, 0>, nullptr, nullptr>' requested here
#   elementwise_check([](double x) { return std::isfinite(x); }, function, name,
#   ^
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/fun/hypergeometric_pFq.hpp:35:3: note: in instantiation of function template specialization 'stan::math::check_finite<Eigen::Matrix<double, 2, 1, 0>>' requested here
#   check_finite("hypergeometric_pFq", "a", a_ref);
#   ^
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/fun/hypergeometric_2F1.hpp:189:12: note: in instantiation of function template specialization 'stan::math::hypergeometric_pFq<Eigen::Matrix<double, 2, 1, 0>, Eigen::Matrix<double, 1, 1, 0>, double, nullptr, nullptr>' requested here
#     return hypergeometric_pFq(a_args, b_args, z);
#            ^
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/fun/grad_2F1.hpp:190:21: note: in instantiation of function template specialization 'stan::math::hypergeometric_2F1<double, double, double, double, double, boost::optional<double>, nullptr>' requested here
#       auto hyper1 = hypergeometric_2F1(a1_euler, a2_euler, b1, z_euler);
#                     ^
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/fun/grad_2F1.hpp:307:20: note: in instantiation of function template specialization 'stan::math::internal::grad_2F1_impl<true, true, true, true, double, double, double, double, double, std::tuple<double, double, double, double>>' requested here
#   return internal::grad_2F1_impl<true, true, true, true>(a1, a2, b1, z,
#                    ^
# In file included from /home/mantyke1/.cache/httpstan/4.6.1/models/tlxohk6n/model_tlxohk6n.cpp:2:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/model/model_header.hpp:4:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math.hpp:19:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/rev.hpp:8:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/rev/core.hpp:53:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/rev/core/profiling.hpp:9:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/err.hpp:4:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/err/check_2F1_converges.hpp:5:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/err/check_not_nan.hpp:5:
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/err/elementwise_check.hpp:153:24: warning: comparison of integers of different signs: 'size_t' (aka 'unsigned long') and 'Eigen::EigenBase::Index' (aka 'long') [-Wsign-compare]
#   for (size_t i = 0; i < x.size(); i++) {
#                      ~ ^ ~~~~~~~~
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/err/check_finite.hpp:29:3: note: in instantiation of function template specialization 'stan::math::elementwise_check<(lambda at /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/err/check_finite.hpp:29:21), Eigen::Matrix<double, 1, 1, 0>, nullptr, nullptr>' requested here
#   elementwise_check([](double x) { return std::isfinite(x); }, function, name,
#   ^
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/fun/hypergeometric_pFq.hpp:36:3: note: in instantiation of function template specialization 'stan::math::check_finite<Eigen::Matrix<double, 1, 1, 0>>' requested here
#   check_finite("hypergeometric_pFq", "b", b_ref);
#   ^
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/fun/hypergeometric_2F1.hpp:189:12: note: in instantiation of function template specialization 'stan::math::hypergeometric_pFq<Eigen::Matrix<double, 2, 1, 0>, Eigen::Matrix<double, 1, 1, 0>, double, nullptr, nullptr>' requested here
#     return hypergeometric_pFq(a_args, b_args, z);
#            ^
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/fun/grad_2F1.hpp:190:21: note: in instantiation of function template specialization 'stan::math::hypergeometric_2F1<double, double, double, double, double, boost::optional<double>, nullptr>' requested here
#       auto hyper1 = hypergeometric_2F1(a1_euler, a2_euler, b1, z_euler);
#                     ^
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/fun/grad_2F1.hpp:307:20: note: in instantiation of function template specialization 'stan::math::internal::grad_2F1_impl<true, true, true, true, double, double, double, double, double, std::tuple<double, double, double, double>>' requested here
#   return internal::grad_2F1_impl<true, true, true, true>(a1, a2, b1, z,
#                    ^
# In file included from /home/mantyke1/.cache/httpstan/4.6.1/models/tlxohk6n/model_tlxohk6n.cpp:2:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/model/model_header.hpp:4:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math.hpp:19:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/rev.hpp:8:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/rev/core.hpp:53:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/rev/core/profiling.hpp:9:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/err.hpp:4:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/err/check_2F1_converges.hpp:5:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/err/check_not_nan.hpp:5:
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/err/elementwise_check.hpp:153:24: warning: comparison of integers of different signs: 'size_t' (aka 'unsigned long') and 'Eigen::EigenBase::Index' (aka 'long') [-Wsign-compare]
#   for (size_t i = 0; i < x.size(); i++) {
#                      ~ ^ ~~~~~~~~
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/err/check_not_nan.hpp:28:3: note: in instantiation of function template specialization 'stan::math::elementwise_check<(lambda at /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/err/check_not_nan.hpp:28:21), Eigen::Matrix<double, 2, 1, 0>, nullptr, nullptr>' requested here
#   elementwise_check([](double x) { return !std::isnan(x); }, function, name, y,
#   ^
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/fun/hypergeometric_pFq.hpp:39:3: note: in instantiation of function template specialization 'stan::math::check_not_nan<Eigen::Matrix<double, 2, 1, 0>>' requested here
#   check_not_nan("hypergeometric_pFq", "a", a_ref);
#   ^
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/fun/hypergeometric_2F1.hpp:189:12: note: in instantiation of function template specialization 'stan::math::hypergeometric_pFq<Eigen::Matrix<double, 2, 1, 0>, Eigen::Matrix<double, 1, 1, 0>, double, nullptr, nullptr>' requested here
#     return hypergeometric_pFq(a_args, b_args, z);
#            ^
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/fun/grad_2F1.hpp:190:21: note: in instantiation of function template specialization 'stan::math::hypergeometric_2F1<double, double, double, double, double, boost::optional<double>, nullptr>' requested here
#       auto hyper1 = hypergeometric_2F1(a1_euler, a2_euler, b1, z_euler);
#                     ^
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/fun/grad_2F1.hpp:307:20: note: in instantiation of function template specialization 'stan::math::internal::grad_2F1_impl<true, true, true, true, double, double, double, double, double, std::tuple<double, double, double, double>>' requested here
#   return internal::grad_2F1_impl<true, true, true, true>(a1, a2, b1, z,
#                    ^
# In file included from /home/mantyke1/.cache/httpstan/4.6.1/models/tlxohk6n/model_tlxohk6n.cpp:2:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/model/model_header.hpp:4:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math.hpp:19:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/rev.hpp:8:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/rev/core.hpp:53:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/rev/core/profiling.hpp:9:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/err.hpp:4:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/err/check_2F1_converges.hpp:5:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/err/check_not_nan.hpp:5:
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/err/elementwise_check.hpp:153:24: warning: comparison of integers of different signs: 'size_t' (aka 'unsigned long') and 'Eigen::EigenBase::Index' (aka 'long') [-Wsign-compare]
#   for (size_t i = 0; i < x.size(); i++) {
#                      ~ ^ ~~~~~~~~
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/err/check_not_nan.hpp:28:3: note: in instantiation of function template specialization 'stan::math::elementwise_check<(lambda at /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/err/check_not_nan.hpp:28:21), Eigen::Matrix<double, 1, 1, 0>, nullptr, nullptr>' requested here
#   elementwise_check([](double x) { return !std::isnan(x); }, function, name, y,
#   ^
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/fun/hypergeometric_pFq.hpp:40:3: note: in instantiation of function template specialization 'stan::math::check_not_nan<Eigen::Matrix<double, 1, 1, 0>>' requested here
#   check_not_nan("hypergeometric_pFq", "b", b_ref);
#   ^
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/fun/hypergeometric_2F1.hpp:189:12: note: in instantiation of function template specialization 'stan::math::hypergeometric_pFq<Eigen::Matrix<double, 2, 1, 0>, Eigen::Matrix<double, 1, 1, 0>, double, nullptr, nullptr>' requested here
#     return hypergeometric_pFq(a_args, b_args, z);
#            ^
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/fun/grad_2F1.hpp:190:21: note: in instantiation of function template specialization 'stan::math::hypergeometric_2F1<double, double, double, double, double, boost::optional<double>, nullptr>' requested here
#       auto hyper1 = hypergeometric_2F1(a1_euler, a2_euler, b1, z_euler);
#                     ^
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/fun/grad_2F1.hpp:307:20: note: in instantiation of function template specialization 'stan::math::internal::grad_2F1_impl<true, true, true, true, double, double, double, double, double, std::tuple<double, double, double, double>>' requested here
#   return internal::grad_2F1_impl<true, true, true, true>(a1, a2, b1, z,
#                    ^
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/fun/grad_2F1.hpp:192:12: warning: unused variable 'pre_mult' [-Wunused-variable]
#       auto pre_mult = a2 * pow(1 - z, -1 - a2);
#            ^
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/fun/grad_2F1.hpp:307:20: note: in instantiation of function template specialization 'stan::math::internal::grad_2F1_impl<true, true, true, true, stan::math::var_value<double>, stan::math::var_value<double>, stan::math::var_value<double>, stan::math::var_value<double>, stan::math::var_value<double>, std::tuple<stan::math::var_value<double>, stan::math::var_value<double>, stan::math::var_value<double>, stan::math::var_value<double>>>' requested here
#   return internal::grad_2F1_impl<true, true, true, true>(a1, a2, b1, z,
#                    ^
# In file included from /home/mantyke1/.cache/httpstan/4.6.1/models/tlxohk6n/model_tlxohk6n.cpp:2:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/model/model_header.hpp:4:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math.hpp:19:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/rev.hpp:8:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/rev/core.hpp:29:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/rev/core/operator_divide_equal.hpp:5:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/rev/core/operator_division.hpp:13:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/rev/core/operator_multiplication.hpp:7:
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/rev/core/operator_subtraction.hpp:104:21: warning: lambda capture 'a' is not used [-Wunused-lambda-capture]
#       [bvi = b.vi_, a](const auto& vi) mutable { bvi->adj_ -= vi.adj_; });
#                     ^
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/fun/grad_2F1.hpp:191:50: note: in instantiation of function template specialization 'stan::math::operator-<int, nullptr>' requested here
#       auto hyper2 = hypergeometric_2F1(1 + a2, 1 - a1 + b1, 1 + b1, z_euler);
#                                                  ^
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/fun/grad_2F1.hpp:307:20: note: in instantiation of function template specialization 'stan::math::internal::grad_2F1_impl<true, true, true, true, stan::math::var_value<double>, stan::math::var_value<double>, stan::math::var_value<double>, stan::math::var_value<double>, stan::math::var_value<double>, std::tuple<stan::math::var_value<double>, stan::math::var_value<double>, stan::math::var_value<double>, stan::math::var_value<double>>>' requested here
#   return internal::grad_2F1_impl<true, true, true, true>(a1, a2, b1, z,
#                    ^
# In file included from /home/mantyke1/.cache/httpstan/4.6.1/models/tlxohk6n/model_tlxohk6n.cpp:2:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/model/model_header.hpp:4:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math.hpp:19:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/rev.hpp:8:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/rev/core.hpp:29:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/rev/core/operator_divide_equal.hpp:5:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/rev/core/operator_division.hpp:13:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/rev/core/operator_multiplication.hpp:7:
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/rev/core/operator_subtraction.hpp:104:21: warning: lambda capture 'a' is not used [-Wunused-lambda-capture]
#       [bvi = b.vi_, a](const auto& vi) mutable { bvi->adj_ -= vi.adj_; });
#                     ^
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/fun/grad_2F1.hpp:208:38: note: in instantiation of function template specialization 'stan::math::operator-<double, nullptr>' requested here
#       auto pre_mult_ab = inv(pow(1.0 - z, a2));
#                                      ^
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/fun/grad_2F1.hpp:307:20: note: in instantiation of function template specialization 'stan::math::internal::grad_2F1_impl<true, true, true, true, stan::math::var_value<double>, stan::math::var_value<double>, stan::math::var_value<double>, stan::math::var_value<double>, stan::math::var_value<double>, std::tuple<stan::math::var_value<double>, stan::math::var_value<double>, stan::math::var_value<double>, stan::math::var_value<double>>>' requested here
#   return internal::grad_2F1_impl<true, true, true, true>(a1, a2, b1, z,
#                    ^
# In file included from /home/mantyke1/.cache/httpstan/4.6.1/models/tlxohk6n/model_tlxohk6n.cpp:2:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/model/model_header.hpp:4:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math.hpp:19:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/rev.hpp:8:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/rev/core.hpp:53:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/rev/core/profiling.hpp:9:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/err.hpp:4:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/err/check_2F1_converges.hpp:5:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/err/check_not_nan.hpp:5:
# ...
#   check_finite(function, "Location parameter", mu_val);
#   ^
# /home/mantyke1/.cache/httpstan/4.6.1/models/tlxohk6n/model_tlxohk6n.cpp:132:36: note: in instantiation of function template specialization 'stan::math::normal_lpdf<false, std::vector<double>, Eigen::Matrix<double, -1, 1, 0>, std::vector<double>, nullptr>' requested here
#         lp_accum__.add(stan::math::normal_lpdf<false>(y, theta, sigma));
#                                    ^
# /home/mantyke1/.cache/httpstan/4.6.1/models/tlxohk6n/model_tlxohk6n.cpp:401:12: note: in instantiation of function template specialization 'model_tlxohk6n_namespace::model_tlxohk6n::log_prob_impl<false, false, Eigen::Matrix<double, -1, 1, 0>, Eigen::Matrix<int, -1, 1, 0>, nullptr, nullptr>' requested here
#     return log_prob_impl<propto__, jacobian__>(params_r, params_i, pstream);
#            ^
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/model/model_base_crtp.hpp:93:50: note: in instantiation of function template specialization 'model_tlxohk6n_namespace::model_tlxohk6n::log_prob<false, false, double>' requested here
#     return static_cast<const M*>(this)->template log_prob<false, false, double>(
#                                                  ^
# /home/mantyke1/.cache/httpstan/4.6.1/models/tlxohk6n/model_tlxohk6n.cpp:28:3: note: in instantiation of member function 'stan::model::model_base_crtp<model_tlxohk6n_namespace::model_tlxohk6n>::log_prob' requested here
#   ~model_tlxohk6n() {}
#   ^
# In file included from /home/mantyke1/.cache/httpstan/4.6.1/models/tlxohk6n/model_tlxohk6n.cpp:2:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/model/model_header.hpp:4:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math.hpp:19:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/rev.hpp:8:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/rev/core.hpp:53:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/rev/core/profiling.hpp:9:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/err.hpp:4:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/err/check_2F1_converges.hpp:5:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/err/check_not_nan.hpp:5:
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/err/elementwise_check.hpp:153:24: warning: comparison of integers of different signs: 'size_t' (aka 'unsigned long') and 'Eigen::EigenBase::Index' (aka 'long') [-Wsign-compare]
#   for (size_t i = 0; i < x.size(); i++) {
#                      ~ ^ ~~~~~~~~
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/err/check_positive.hpp:29:3: note: in instantiation of function template specialization 'stan::math::elementwise_check<(lambda at /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/err/check_positive.hpp:29:21), Eigen::ArrayWrapper<Eigen::Map<const Eigen::Matrix<double, -1, 1, 0>, 0>>, nullptr, nullptr>' requested here
#   elementwise_check([](double x) { return x > 0; }, function, name, y,
#   ^
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/prob/normal_lpdf.hpp:64:3: note: in instantiation of function template specialization 'stan::math::check_positive<Eigen::ArrayWrapper<Eigen::Map<const Eigen::Matrix<double, -1, 1, 0>, 0>>>' requested here
#   check_positive(function, "Scale parameter", sigma_val);
#   ^
# /home/mantyke1/.cache/httpstan/4.6.1/models/tlxohk6n/model_tlxohk6n.cpp:132:36: note: in instantiation of function template specialization 'stan::math::normal_lpdf<false, std::vector<double>, Eigen::Matrix<double, -1, 1, 0>, std::vector<double>, nullptr>' requested here
#         lp_accum__.add(stan::math::normal_lpdf<false>(y, theta, sigma));
#                                    ^
# /home/mantyke1/.cache/httpstan/4.6.1/models/tlxohk6n/model_tlxohk6n.cpp:401:12: note: in instantiation of function template specialization 'model_tlxohk6n_namespace::model_tlxohk6n::log_prob_impl<false, false, Eigen::Matrix<double, -1, 1, 0>, Eigen::Matrix<int, -1, 1, 0>, nullptr, nullptr>' requested here
#     return log_prob_impl<propto__, jacobian__>(params_r, params_i, pstream);
#            ^
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/model/model_base_crtp.hpp:93:50: note: in instantiation of function template specialization 'model_tlxohk6n_namespace::model_tlxohk6n::log_prob<false, false, double>' requested here
#     return static_cast<const M*>(this)->template log_prob<false, false, double>(
#                                                  ^
# /home/mantyke1/.cache/httpstan/4.6.1/models/tlxohk6n/model_tlxohk6n.cpp:28:3: note: in instantiation of member function 'stan::model::model_base_crtp<model_tlxohk6n_namespace::model_tlxohk6n>::log_prob' requested here
#   ~model_tlxohk6n() {}
#   ^
# In file included from /home/mantyke1/.cache/httpstan/4.6.1/models/tlxohk6n/model_tlxohk6n.cpp:2:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/model/model_header.hpp:4:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math.hpp:19:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/rev.hpp:10:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/rev/fun.hpp:100:
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/rev/fun/lb_constrain.hpp:114:33: warning: lambda capture 'lp' is not used [-Wunused-lambda-capture]
#                                [lp, arena_lb = var(lb)](auto& vi) mutable {
#                                 ^
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/io/deserializer.hpp:386:26: note: in instantiation of function template specialization 'stan::math::lb_constrain<stan::math::var_value<double>, int, nullptr, nullptr>' requested here
#       return stan::math::lb_constrain(this->read<Ret>(sizes...), lb, lp);
#                          ^
# /home/mantyke1/.cache/httpstan/4.6.1/models/tlxohk6n/model_tlxohk6n.cpp:116:27: note: in instantiation of function template specialization 'stan::io::deserializer<stan::math::var_value<double>>::read_constrain_lb<stan::math::var_value<double>, false, int, stan::math::var_value<double>>' requested here
#       tau = in__.template read_constrain_lb<local_scalar_t__, jacobian__>(0,
#                           ^
# /home/mantyke1/.cache/httpstan/4.6.1/models/tlxohk6n/model_tlxohk6n.cpp:401:12: note: in instantiation of function template specialization 'model_tlxohk6n_namespace::model_tlxohk6n::log_prob_impl<false, false, Eigen::Matrix<stan::math::var_value<double>, -1, 1, 0>, Eigen::Matrix<int, -1, 1, 0>, nullptr, nullptr>' requested here
#     return log_prob_impl<propto__, jacobian__>(params_r, params_i, pstream);
#            ^
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/model/model_base_crtp.hpp:98:50: note: in instantiation of function template specialization 'model_tlxohk6n_namespace::model_tlxohk6n::log_prob<false, false, stan::math::var_value<double>>' requested here
#     return static_cast<const M*>(this)->template log_prob<false, false>(theta,
#                                                  ^
# /home/mantyke1/.cache/httpstan/4.6.1/models/tlxohk6n/model_tlxohk6n.cpp:28:3: note: in instantiation of member function 'stan::model::model_base_crtp<model_tlxohk6n_namespace::model_tlxohk6n>::log_prob' requested here
#   ~model_tlxohk6n() {}
#   ^
# In file included from /home/mantyke1/.cache/httpstan/4.6.1/models/tlxohk6n/model_tlxohk6n.cpp:2:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/model/model_header.hpp:4:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math.hpp:19:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/rev.hpp:8:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/rev/core.hpp:53:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/rev/core/profiling.hpp:9:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/err.hpp:4:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/err/check_2F1_converges.hpp:5:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/err/check_not_nan.hpp:5:
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/err/elementwise_check.hpp:153:24: warning: comparison of integers of different signs: 'size_t' (aka 'unsigned long') and 'Eigen::EigenBase::Index' (aka 'long') [-Wsign-compare]
#   for (size_t i = 0; i < x.size(); i++) {
#                      ~ ^ ~~~~~~~~
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/err/check_not_nan.hpp:28:3: note: in instantiation of function template specialization 'stan::math::elementwise_check<(lambda at /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/err/check_not_nan.hpp:28:21), Eigen::Array<double, -1, 1, 0>, nullptr, nullptr>' requested here
#   elementwise_check([](double x) { return !std::isnan(x); }, function, name, y,
#   ^
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/prob/normal_lpdf.hpp:62:3: note: in instantiation of function template specialization 'stan::math::check_not_nan<Eigen::Array<double, -1, 1, 0>>' requested here
#   check_not_nan(function, "Random variable", y_val);
#   ^
# /home/mantyke1/.cache/httpstan/4.6.1/models/tlxohk6n/model_tlxohk6n.cpp:130:36: note: in instantiation of function template specialization 'stan::math::normal_lpdf<false, Eigen::Matrix<stan::math::var_value<double>, -1, 1, 0>, int, int, nullptr>' requested here
#         lp_accum__.add(stan::math::normal_lpdf<false>(eta, 0, 1));
#                                    ^
# /home/mantyke1/.cache/httpstan/4.6.1/models/tlxohk6n/model_tlxohk6n.cpp:401:12: note: in instantiation of function template specialization 'model_tlxohk6n_namespace::model_tlxohk6n::log_prob_impl<false, false, Eigen::Matrix<stan::math::var_value<double>, -1, 1, 0>, Eigen::Matrix<int, -1, 1, 0>, nullptr, nullptr>' requested here
#     return log_prob_impl<propto__, jacobian__>(params_r, params_i, pstream);
#            ^
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/model/model_base_crtp.hpp:98:50: note: in instantiation of function template specialization 'model_tlxohk6n_namespace::model_tlxohk6n::log_prob<false, false, stan::math::var_value<double>>' requested here
#     return static_cast<const M*>(this)->template log_prob<false, false>(theta,
#                                                  ^
# /home/mantyke1/.cache/httpstan/4.6.1/models/tlxohk6n/model_tlxohk6n.cpp:28:3: note: in instantiation of member function 'stan::model::model_base_crtp<model_tlxohk6n_namespace::model_tlxohk6n>::log_prob' requested here
#   ~model_tlxohk6n() {}
#   ^
# In file included from /home/mantyke1/.cache/httpstan/4.6.1/models/tlxohk6n/model_tlxohk6n.cpp:2:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/model/model_header.hpp:4:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math.hpp:19:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/rev.hpp:8:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/rev/core.hpp:53:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/rev/core/profiling.hpp:9:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/err.hpp:4:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/err/check_2F1_converges.hpp:5:
# In file included from /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/err/check_not_nan.hpp:5:
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/err/elementwise_check.hpp:153:24: warning: comparison of integers of different signs: 'size_t' (aka 'unsigned long') and 'Eigen::EigenBase::Index' (aka 'long') [-Wsign-compare]
#   for (size_t i = 0; i < x.size(); i++) {
#                      ~ ^ ~~~~~~~~
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/err/check_finite.hpp:29:3: note: in instantiation of function template specialization 'stan::math::elementwise_check<(lambda at /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/err/check_finite.hpp:29:21), Eigen::Array<double, -1, 1, 0>, nullptr, nullptr>' requested here
#   elementwise_check([](double x) { return std::isfinite(x); }, function, name,
#   ^
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/math/prim/prob/normal_lpdf.hpp:63:3: note: in instantiation of function template specialization 'stan::math::check_finite<Eigen::Array<double, -1, 1, 0>>' requested here
#   check_finite(function, "Location parameter", mu_val);
#   ^
# /home/mantyke1/.cache/httpstan/4.6.1/models/tlxohk6n/model_tlxohk6n.cpp:132:36: note: in instantiation of function template specialization 'stan::math::normal_lpdf<false, std::vector<double>, Eigen::Matrix<stan::math::var_value<double>, -1, 1, 0>, std::vector<double>, nullptr>' requested here
#         lp_accum__.add(stan::math::normal_lpdf<false>(y, theta, sigma));
#                                    ^
# /home/mantyke1/.cache/httpstan/4.6.1/models/tlxohk6n/model_tlxohk6n.cpp:401:12: note: in instantiation of function template specialization 'model_tlxohk6n_namespace::model_tlxohk6n::log_prob_impl<false, false, Eigen::Matrix<stan::math::var_value<double>, -1, 1, 0>, Eigen::Matrix<int, -1, 1, 0>, nullptr, nullptr>' requested here
#     return log_prob_impl<propto__, jacobian__>(params_r, params_i, pstream);
#            ^
# /opt/software/lib/python3.10/site-packages/httpstan/include/stan/model/model_base_crtp.hpp:98:50: note: in instantiation of function template specialization 'model_tlxohk6n_namespace::model_tlxohk6n::log_prob<false, false, stan::math::var_value<double>>' requested here
#     return static_cast<const M*>(this)->template log_prob<false, false>(theta,
#                                                  ^
# /home/mantyke1/.cache/httpstan/4.6.1/models/tlxohk6n/model_tlxohk6n.cpp:28:3: note: in instantiation of member function 'stan::model::model_base_crtp<model_tlxohk6n_namespace::model_tlxohk6n>::log_prob' requested here
#   ~model_tlxohk6n() {}
#   ^
# 78 warnings generated.
# Building: 17.2s, done.Messages from stanc:
# Warning: The parameter tau has no priors. This means either no prior is
#     provided, or the prior(s) depend on data variables. In the later case,
#     this may be a false positive.
# Warning: The parameter mu has no priors. This means either no prior is
#     provided, or the prior(s) depend on data variables. In the later case,
#     this may be a false positive.
# Sampling:   0%
# Sampling:  25% (2000/8000)
# Sampling:  50% (4000/8000)
# Sampling:  75% (6000/8000)
# Sampling: 100% (8000/8000)
# Sampling: 100% (8000/8000), done.
# Messages received during sampling:
#   Gradient evaluation took 1.7e-05 seconds
#   1000 transitions using 10 leapfrog steps per transition would take 0.17 seconds.
#   Adjust your expectations accordingly!
#   Gradient evaluation took 2e-05 seconds
#   1000 transitions using 10 leapfrog steps per transition would take 0.2 seconds.
#   Adjust your expectations accordingly!
#   Gradient evaluation took 2.2e-05 seconds
#   1000 transitions using 10 leapfrog steps per transition would take 0.22 seconds.
#   Adjust your expectations accordingly!
#   Gradient evaluation took 2.2e-05 seconds
#   1000 transitions using 10 leapfrog steps per transition would take 0.22 seconds.
#   Adjust your expectations accordingly!
