# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("data.csv", header=5, index_col=0)
df = df.shift(axis=1)
df.head(10)
# Out:
#    Region Code Region Name Country Code Country Name  Year  Sex  \
# EU        None      Europe          ALB      Albania  1987  All
# EU        None      Europe          ALB      Albania  1987  All
# EU        None      Europe          ALB      Albania  1987  All
# EU        None      Europe          ALB      Albania  1987  All
# EU        None      Europe          ALB      Albania  1987  All
# EU        None      Europe          ALB      Albania  1987  All
# EU        None      Europe          ALB      Albania  1987  All
# EU        None      Europe          ALB      Albania  1987  All
# EU        None      Europe          ALB      Albania  1987  All
# EU        None      Europe          ALB      Albania  1987  All
#
#    Age group code  Age Group  Number  \
# EU    Age_unknown  [Unknown]     0.0
# EU     Age85_over      [85+]     2.0
# EU       Age80_84    [80-84]     0.0
# EU       Age75_79    [75-79]     6.0
# EU       Age70_74    [70-74]     9.0
# EU       Age65_69    [65-69]     8.0
# EU       Age60_64    [60-64]     8.0
# EU       Age55_59    [55-59]    17.0
# EU       Age50_54    [50-54]    14.0
# EU       Age45_49    [45-49]    21.0
#
#     Percentage of cause-specific deaths out of total deaths  \
# EU                                                NaN
# EU                                           0.089847
# EU                                           0.000000
# EU                                           0.283688
# EU                                           0.498339
# EU                                           0.578453
# EU                                           0.755430
# EU                                           2.096178
# EU                                           2.729045
# EU                                           5.329949
#
#     Age-standardized death rate per 100 000 standard population  \
# EU                                                NaN
# EU                                                NaN
# EU                                                NaN
# EU                                                NaN
# EU                                                NaN
# EU                                                NaN
# EU                                                NaN
# EU                                                NaN
# EU                                                NaN
# EU                                                NaN
#
#     Death rate per 100 000 population
# EU                                NaN
# EU                          20.000000
# EU                           0.000000
# EU                          19.480519
# EU                          22.058824
# EU                          12.364760
# EU                          10.335917
# EU                          17.137097
# EU                          11.637573
# EU                          14.788732

# %%
df = df[df['Country Code'] == 'USA']
df = df[df['Year'] > 2011]
df.head()
# Out:
#     Region Code                      Region Name Country Code  \
# NAC        None  North America and the Caribbean          USA
# NAC        None  North America and the Caribbean          USA
# NAC        None  North America and the Caribbean          USA
# NAC        None  North America and the Caribbean          USA
# NAC        None  North America and the Caribbean          USA
#
#                  Country Name  Year  Sex Age group code  Age Group   Number  \
# NAC  United States of America  2012  All    Age_unknown  [Unknown]      5.0
# NAC  United States of America  2012  All        Age_all      [All]  36099.0
# NAC  United States of America  2012  All          Age00        [0]     69.0
# NAC  United States of America  2012  All       Age01_04      [1-4]    365.0
# NAC  United States of America  2012  All       Age05_09      [5-9]    343.0
#
#      Percentage of cause-specific deaths out of total deaths  \
# NAC                                           3.401361
# NAC                                           1.419388
# NAC                                           0.292014
# NAC                                           8.653390
# NAC                                          14.695801
#
#      Age-standardized death rate per 100 000 standard population  \
# NAC                                                NaN
# NAC                                          10.696564
# NAC                                                NaN
# NAC                                                NaN
# NAC                                                NaN
#
#      Death rate per 100 000 population
# NAC                                NaN
# NAC                          11.494890
# NAC                           1.724506
# NAC                           2.188495
# NAC                           1.650384
